# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.data_loader import *
import pandas as pd
from urllib.parse import unquote

# %% [markdown]
# ## What articles do we have in the data?

# %%
parser = htmlParser()
print(f'There are {len(parser.article_URLs)} valid articles')
# Out:
# There are 5232 valid articles

# %%
df_html_articles = parser.article_names # The html articles in the data
df_article_names = read_articles() # The articles used in the paths-and-graph data
intersect = pd.merge(df_html_articles, df_article_names, how='inner', on="article")
print(f'There are {len(df_article_names)} articles in the paths-and-graph data and {len(intersect)} of those are in the html articles (Oof).')
# Out:
# There are 4604 articles in the paths-and-graph data and 4604 of those are in the html articles (Oof).

# %%
difference = df_html_articles[~df_html_articles.isin(df_article_names)]
print(f'This means there are {len(difference)} articles more in the html data, such as "{difference.iloc[0]}", "{difference.iloc[5]}" or "{difference.iloc[10]}".')
# Out:
# This means there are 628 articles more in the html data, such as "2006 Autumn Newsletter Focus On Bethlehem", "About Child Sponsorship" or "Aids Africa".

# %% [markdown]
# ## Parsing
# Example of parsing for a single file. The individual links are also saved but not shown

# %%
parsed = parser.parse_html_article(parser.article_URLs[266]) # Azerbaijan as example: 498
if parsed: parser.get_overview(parsed)
# Out:
# Page Overview
# -------------
# Title: Amazon Rainforest
# Total Words: 1554
# Total Links: 33
#
# Abstract Overview
# -----------------
# Abstract Length (words): 156
# Abstract Links: 14
#
# Categories and Subcategories Overview
# -------------------------------------
# Category 1: Etymology
#  - Words: 53
#  - Links: 3
#
# Category 2: Biodiversity
#  - Words: 243
#  - Links: 8
#
# Category 3: Deforestation
#  - Words: 261
#  - Links: 1
#
# Category 4: Carbon dynamics
#  - Words: 155
#  - Links: 4
#
# Category 5: Conservation
#  - Words: 251
#  - Links: 1
#
# Category 6: Response to climate change
#  - Words: 410
#  - Links: 1
#    Subcategory 1: Impact of Amazon drought
#    - Words: 162
#    - Links: 0
#
# Category 7: Video
#  - Words: 14
#  - Links: 0
#
# Tables Overview
# ---------------

# %%
# this parses the first 100 articles that are actually those used in paths-and-graphs

indices_only_in_paths_and_graph = [i for i in df_html_articles.index if df_html_articles[i] in df_article_names.values]
parser.parse_selection(indices_only_in_paths_and_graph[:100])
# parser.parse_all() # to parse everything
# Out:
# 100%|██████████| 100/100 [00:08<00:00, 11.41it/s]

# %%
# parser allows for pickle saving...

parser.save_pickle()

# %%
# ... and loading

parser2 = htmlParser()
parser.load_pickle()
parser.parsed_articles
# Out:
# {'Áedán mac Gabráin': {'title': 'Áedán mac Gabráin',
#   'total_words': 1841,
#   'total_links': ['../../wp/d/D%25C3%25A1l_Riata.htm',
#    '../../wp/m/Monarchy.htm',
#    '../../wp/s/Scotland.htm',
#    '../../wp/i/Ireland.htm',
#    '../../wp/c/Columba.htm',
#    '../../wp/i/Ireland.htm',
#    '../../wp/g/Great_Britain.htm',
#    '../../wp/o/Orkney.htm',
#    '../../wp/i/Isle_of_Man.htm',
#    '../../wp/b/Bede.htm',
#    '../../wp/p/Picts.htm',
#    '../../wp/w/Wales.htm'],
#   'abstract_length': 169,
#   'abstract_links': ['../../wp/d/D%25C3%25A1l_Riata.htm',
#    '../../wp/m/Monarchy.htm',
#    '../../wp/s/Scotland.htm',
#    '../../wp/i/Ireland.htm',
#    '../../wp/c/Columba.htm',
#    '../../wp/i/Ireland.htm',
#    '../../wp/g/Great_Britain.htm',
#    '../../wp/o/Orkney.htm',
#    '../../wp/i/Isle_of_Man.htm',
#    '../../wp/b/Bede.htm'],
#   'categories_data': [{'name': 'Background',
#     'num_words': 312,
#     'h2_links': [],
#     'subcategories': []},
#    {'name': 'Neighbours',
#     'num_words': 225,
#     'h2_links': ['../../wp/p/Picts.htm'],
#     'subcategories': []},
#    {'name': 'Reign',
#     'num_words': 566,
#     'h2_links': ['../../wp/w/Wales.htm'],
#     'subcategories': []},
#    {'name': 'Degsastan and after',
#     'num_words': 300,
#     'h2_links': [],
#     'subcategories': []},
#    {'name': "Áedán's legacy",
#     'num_words': 261,
#     'h2_links': [],
#     'subcategories': []}],
#   'tables': []},
#  'Åland': {'title': 'Åland',
#   'total_words': 2387,
#   'total_links': ['../../wp/l/List_of_countries_by_system_of_government.htm',
#    '../../wp/e/European_Union.htm',
#    '../../wp/c/Currency.htm',
#    '../../wp/e/Euro.htm',
#    '../../wp/t/Time_zone.htm',
#    '../../wp/l/League_of_Nations.htm',
#    '../../wp/b/Baltic_Sea.htm',
#    '../../wp/f/Finland.htm',
#    '../../wp/s/Sweden.htm',
#    '../../wp/l/League_of_Nations.htm',
#    '../../wp/e/European_Union.htm',
#    '../../wp/e/European_Union.htm',
#    '../../wp/n/Nationality.htm',
#    '../../wp/r/Russia.htm',
#    '../../wp/s/Sweden.htm',
#    '../../wp/u/United_Kingdom.htm',
#    '../../wp/c/Crimean_War.htm',
#    '../../wp/l/League_of_Nations.htm',
#    '../../wp/2/20th_century.htm',
#    '../../wp/w/World_War_II.htm',
#    '../../wp/c/Crimean_War.htm',
#    '../../wp/p/Parliamentary_system.htm',
#    '../../wp/p/Police.htm',
#    '../../wp/s/Stockholm.htm',
#    '../../wp/t/Tourism.htm',
#    '../../wp/e/European_Union.htm',
#    '../../wp/f/Finland.htm'],
#   'abstract_length': 400,
#   'abstract_links': ['../../wp/l/List_of_countries_by_system_of_government.htm',
#    '../../wp/e/European_Union.htm',
#    '../../wp/c/Currency.htm',
#    '../../wp/e/Euro.htm',
#    '../../wp/t/Time_zone.htm',
#    '../../wp/l/League_of_Nations.htm',
#    '../../wp/b/Baltic_Sea.htm',
#    '../../wp/f/Finland.htm',
#    '../../wp/s/Sweden.htm'],
#   'categories_data': [{'name': 'Autonomy of Åland',
#     'num_words': 154,
#     'h2_links': ['../../wp/l/League_of_Nations.htm',
#      '../../wp/e/European_Union.htm',
#      '../../wp/e/European_Union.htm',
#      '../../wp/n/Nationality.htm'],
#     'subcategories': []},
#    {'name': 'History',
#     'num_words': 545,
#     'h2_links': ['../../wp/r/Russia.htm',
#      '../../wp/s/Sweden.htm',
#      '../../wp/u/United_Kingdom.htm',
#      '../../wp/c/Crimean_War.htm',
#      '../../wp/l/League_of_Nations.htm',
#      '../../wp/2/20th_century.htm',
#      '../../wp/w/World_War_II.htm'],
#     'subcategories': []},
#    {'name': 'Politics',
#     'num_words': 144,
#     'h2_links': ['../../wp/c/Crimean_War.htm',
#      '../../wp/p/Parliamentary_system.htm',
#      '../../wp/p/Police.htm'],
#     'subcategories': []},
#    {'name': 'Administration',
#     'num_words': 130,
#     'h2_links': [],
#     'subcategories': []},
#    {'name': 'Municipalities',
#     'num_words': 16,
#     'h2_links': [],
#     'subcategories': []},
#    {'name': 'Geography',
#     'num_words': 355,
#     'h2_links': ['../../wp/s/Stockholm.htm'],
#     'subcategories': []},
#    {'name': 'Economy',
#     'num_words': 218,
#     'h2_links': ['../../wp/t/Tourism.htm', '../../wp/e/European_Union.htm'],
#     'subcategories': []},
#    {'name': 'Demographics',
#     'num_words': 172,
#     'h2_links': [],
#     'subcategories': []},
#    {'name': 'Culture', 'num_words': 25, 'h2_links': [], 'subcategories': []},
#    {'name': 'Holidays',
#     'num_words': 153,
#     'h2_links': ['../../wp/f/Finland.htm'],
#     'subcategories': []},
#    {'name': 'Gallery', 'num_words': 62, 'h2_links': [], 'subcategories': []}],
#   'tables': [{'class': ['infobox', 'geography'],
#     'num_words': 202,
#     'table_links': ['../../wp/l/List_of_countries_by_system_of_government.htm',
#      '../../wp/e/European_Union.htm',
#      '../../wp/c/Currency.htm',
#      '../../wp/e/Euro.htm',
#      '../../wp/t/Time_zone.htm',
#      '../../wp/l/League_of_Nations.htm']},
#    {'class': None, 'num_words': 4, 'table_links': []},
#    {'class': None, 'num_words': 16, 'table_links': []},
#    {'class': ['toccolours'],
#     'num_words': 153,
#     'table_links': ['../../wp/f/Finland.htm']},
#    {'class': ['gallery'], 'num_words': 58, 'table_links': []}]},
#  'Édouard Manet': {'title': 'Édouard Manet',
#   'total_words': 2901,
#   'total_links': ['../../wp/c/Claude_Monet.htm',
#    '../../wp/p/Paris.htm',
#    '../../wp/p/Paris.htm',
#    '../../wp/f/France.htm',
#    '../../wp/p/Painting.htm',
#    '../../wp/f/France.htm',
#    '../../wp/i/Impressionism.htm',
#    '../../wp/p/Paris.htm',
#    '../../wp/s/Sweden.htm',
#    '../../wp/g/Germany.htm',
#    '../../wp/i/Italy.htm',
#    '../../wp/n/Netherlands.htm',
#    '../../wp/d/Diego_Vel%25C3%25A1zquez.htm',
#    '../../wp/f/Francisco_Goya.htm',
#    '../../wp/a/Absinthe.htm',
#    '../../wp/r/Raphael.htm',
#    '../../wp/r/Renaissance.htm',
#    '../../wp/i/Italy.htm',
#    '../../wp/i/Italy.htm',
#    '../../wp/r/Renaissance.htm',
#    '../../wp/p/Photography.htm',
#    '../../wp/i/Impressionism.htm',
#    '../../wp/c/Claude_Monet.htm',
#    '../../wp/b/Beer.htm',
#    '../../wp/l/Landscape.htm',
#    '../../wp/w/Washington%252C_D.C..htm',
#    '../../wp/e/Edgar_Allan_Poe.htm',
#    '../../wp/u/United_States_dollar.htm'],
#   'abstract_length': 163,
#   'abstract_links': ['../../wp/c/Claude_Monet.htm',
#    '../../wp/p/Paris.htm',
#    '../../wp/p/Paris.htm',
#    '../../wp/f/France.htm',
#    '../../wp/p/Painting.htm',
#    '../../wp/f/France.htm',
#    '../../wp/i/Impressionism.htm'],
#   'categories_data': [{'name': 'Biography',
#     'num_words': 2528,
#     'h2_links': ['../../wp/p/Paris.htm',
#      '../../wp/s/Sweden.htm',
#      '../../wp/g/Germany.htm',
#      '../../wp/i/Italy.htm',
#      '../../wp/n/Netherlands.htm',
#      '../../wp/d/Diego_Vel%25C3%25A1zquez.htm',
#      '../../wp/f/Francisco_Goya.htm',
#      '../../wp/a/Absinthe.htm',
#      '../../wp/r/Raphael.htm',
#      '../../wp/r/Renaissance.htm',
#      '../../wp/i/Italy.htm',
#      '../../wp/i/Italy.htm',
#      '../../wp/r/Renaissance.htm',
#      '../../wp/p/Photography.htm',
#      '../../wp/i/Impressionism.htm',
#      '../../wp/c/Claude_Monet.htm',
#      '../../wp/b/Beer.htm',
#      '../../wp/l/Landscape.htm',
#      '../../wp/w/Washington%252C_D.C..htm',
#      '../../wp/e/Edgar_Allan_Poe.htm'],
#     'subcategories': [{'name': 'Early life',
#       'num_words': 233,
#       'h3_links': ['../../wp/p/Paris.htm',
#        '../../wp/s/Sweden.htm',
#        '../../wp/g/Germany.htm',
#        '../../wp/i/Italy.htm',
#        '../../wp/n/Netherlands.htm',
#        '../../wp/d/Diego_Vel%25C3%25A1zquez.htm',
#        '../../wp/f/Francisco_Goya.htm',
#        '../../wp/a/Absinthe.htm']},
#      {'name': 'Music in the Tuileries', 'num_words': 92, 'h3_links': []},
#      {'name': "Luncheon on the Grass (Le déjeuner sur l'herbe)",
#       'num_words': 244,
#       'h3_links': ['../../wp/r/Raphael.htm',
#        '../../wp/r/Renaissance.htm',
#        '../../wp/i/Italy.htm',
#        '../../wp/i/Italy.htm']},
#      {'name': 'Olympia',
#       'num_words': 283,
#       'h3_links': ['../../wp/r/Renaissance.htm',
#        '../../wp/p/Photography.htm']},
#      {'name': 'Life and times',
#       'num_words': 439,
#       'h3_links': ['../../wp/i/Impressionism.htm',
#        '../../wp/c/Claude_Monet.htm']},
#      {'name': 'Cafe scenes',
#       'num_words': 304,
#       'h3_links': ['../../wp/b/Beer.htm']},
#      {'name': 'Paintings of social activities',
#       'num_words': 168,
#       'h3_links': []},
#      {'name': 'Politics', 'num_words': 366, 'h3_links': []},
#      {'name': 'Paris',
#       'num_words': 294,
#       'h3_links': ['../../wp/l/Landscape.htm',
#        '../../wp/w/Washington%252C_D.C..htm']},
#      {'name': 'Late works',
#       'num_words': 181,
#       'h3_links': ['../../wp/e/Edgar_Allan_Poe.htm']}]},
#    {'name': 'Private life',
#     'num_words': 191,
#     'h2_links': ['../../wp/u/United_States_dollar.htm'],
#     'subcategories': [{'name': 'Death',
#       'num_words': 102,
#       'h3_links': ['../../wp/u/United_States_dollar.htm']}]},
#    {'name': 'Paintings',
#     'num_words': 15,
#     'h2_links': [],
#     'subcategories': []}],
#   'tables': [{'class': ['infobox', 'vcard'],
#     'num_words': 50,
#     'table_links': ['../../wp/p/Paris.htm',
#      '../../wp/p/Paris.htm',
#      '../../wp/f/France.htm',
#      '../../wp/p/Painting.htm']},
#    {'class': ['gallery'], 'num_words': 11, 'table_links': []}]},
#  'Éire': {'title': 'Éire',
#   'total_words': 2047,
#   'total_links': ['../../wp/i/Ireland.htm',
#    '../../wp/e/English_language.htm',
#    '../../wp/i/Ireland.htm',
#    '../../wp/r/Republic_of_Ireland.htm',
#    '../../wp/i/Ireland.htm',
#    '../../wp/r/Republic_of_Ireland.htm',
#    '../../wp/g/George_VI_of_the_United_Kingdom.htm',
#    '../../wp/o/Ottawa.htm',
#    '../../wp/c/Canada.htm',
#    '../../wp/n/Northern_Ireland.htm',
#    '../../wp/u/United_Kingdom.htm',
#    '../../wp/n/Northern_Ireland.htm'],
#   'abstract_length': 339,
#   'abstract_links': ['../../wp/i/Ireland.htm',
#    '../../wp/e/English_language.htm',
#    '../../wp/i/Ireland.htm',
#    '../../wp/r/Republic_of_Ireland.htm',
#    '../../wp/i/Ireland.htm',
#    '../../wp/r/Republic_of_Ireland.htm'],
#   'categories_data': [{'name': 'Éire in the Irish Constitution',
#     'num_words': 218,
#     'h2_links': [],
#     'subcategories': []},
#    {'name': 'From Éire to the Republic of Ireland',
#     'num_words': 1478,
#     'h2_links': ['../../wp/g/George_VI_of_the_United_Kingdom.htm',
#      '../../wp/o/Ottawa.htm',
#      '../../wp/c/Canada.htm',
#      '../../wp/n/Northern_Ireland.htm',
#      '../../wp/u/United_Kingdom.htm',
#      '../../wp/n/Northern_Ireland.htm'],
#     'subcategories': []}],
#   'tables': []},
#  'Óengus I of the Picts': {'title': 'Óengus I of the Picts',
#   'total_words': 2010,
#   'total_links': ['../../wp/l/Lion.htm',
#    '../../wp/d/D%25C3%25A1l_Riata.htm',
#    '../../wp/s/Scotland.htm',
#    '../../wp/i/Ireland.htm',
#    '../../wp/e/England.htm',
#    '../../wp/v/Viking.htm',
#    '../../wp/g/Great_Britain.htm',
#    '../../wp/i/Ireland.htm',
#    '../../wp/d/D%25C3%25A1l_Riata.htm',
#    '../../wp/m/Mercia.htm',
#    '../../wp/y/York.htm',
#    '../../wp/d/Durham.htm'],
#   'abstract_length': 254,
#   'abstract_links': ['../../wp/l/Lion.htm',
#    '../../wp/d/D%25C3%25A1l_Riata.htm',
#    '../../wp/s/Scotland.htm',
#    '../../wp/i/Ireland.htm',
#    '../../wp/e/England.htm',
#    '../../wp/v/Viking.htm'],
#   'categories_data': [{'name': 'Rise to power',
#     'num_words': 226,
#     'h2_links': [],
#     'subcategories': []},
#    {'name': 'Percutio Dal Riatai',
#     'num_words': 480,
#     'h2_links': ['../../wp/g/Great_Britain.htm',
#      '../../wp/i/Ireland.htm',
#      '../../wp/d/D%25C3%25A1l_Riata.htm'],
#     'subcategories': []},
#    {'name': 'Alt Clut, Northumbria, and Mercia',
#     'num_words': 539,
#     'h2_links': ['../../wp/m/Mercia.htm', '../../wp/y/York.htm'],
#     'subcategories': []},
#    {'name': 'The cult of Saint Andrew',
#     'num_words': 201,
#     'h2_links': ['../../wp/d/Durham.htm'],
#     'subcategories': []},
#    {'name': 'Death and legacy',
#     'num_words': 291,
#     'h2_links': [],
#     'subcategories': []}],
#   'tables': [{'class': ['infobox'],
#     'num_words': 81,
#     'table_links': ['../../wp/l/Lion.htm']}]},
#  '€2 commemorative coins': {'title': '€2 commemorative coins',
#   'total_words': 3523,
#   'total_links': ['../../wp/h/History.htm',
#    '../../wp/m/Monaco.htm',
#    '../../wp/v/Vatican_City.htm',
#    '../../wp/p/Pope_John_Paul_II.htm',
#    '../../wp/a/Austria.htm',
#    '../../wp/b/Belgium.htm',
#    '../../wp/f/Finland.htm',
#    '../../wp/g/Germany.htm',
#    '../../wp/g/Greece.htm',
#    '../../wp/i/Italy.htm',
#    '../../wp/l/Luxembourg.htm',
#    '../../wp/s/San_Marino.htm',
#    '../../wp/s/Spain.htm',
#    '../../wp/v/Vatican_City.htm',
#    '../../wp/f/France.htm',
#    '../../wp/i/Ireland.htm',
#    '../../wp/m/Monaco.htm',
#    '../../wp/n/Netherlands.htm',
#    '../../wp/p/Portugal.htm',
#    '../../wp/h/Heraldry.htm',
#    '../../wp/g/Greece.htm',
#    '../../wp/a/Athens.htm',
#    '../../wp/g/Greece.htm',
#    '../../wp/f/Finland.htm',
#    '../../wp/e/European_Union.htm',
#    '../../wp/l/Luxembourg.htm',
#    '../../wp/i/Italy.htm',
#    '../../wp/c/Cereal.htm',
#    '../../wp/m/Maize.htm',
#    '../../wp/r/Rice.htm',
#    '../../wp/w/Wheat.htm',
#    '../../wp/n/Nutrition.htm',
#    '../../wp/i/Italy.htm',
#    '../../wp/s/San_Marino.htm',
#    '../../wp/n/Numismatics.htm',
#    '../../wp/v/Vatican_City.htm',
#    '../../wp/l/Luxembourg.htm',
#    '../../wp/a/Austria.htm',
#    '../../wp/s/Soviet_Union.htm',
#    '../../wp/u/United_States.htm',
#    '../../wp/h/Harold_Macmillan.htm',
#    '../../wp/u/United_Kingdom.htm',
#    '../../wp/f/France.htm',
#    '../../wp/h/Heraldry.htm',
#    '../../wp/b/Belgium.htm',
#    '../../wp/s/Spain.htm',
#    '../../wp/m/Miguel_de_Cervantes.htm',
#    '../../wp/s/San_Marino.htm',
#    '../../wp/g/Galileo_Galilei.htm',
#    '../../wp/f/Finland.htm',
#    '../../wp/u/United_Nations.htm',
#    '../../wp/i/Italy.htm',
#    '../../wp/z/Zeus.htm',
#    '../../wp/v/Vatican_City.htm',
#    '../../wp/c/Cologne.htm',
#    '../../wp/c/Comet.htm',
#    '../../wp/l/Luxembourg.htm',
#    '../../wp/g/Germany.htm',
#    '../../wp/i/Italy.htm',
#    '../../wp/t/Turin.htm',
#    '../../wp/b/Belgium.htm',
#    '../../wp/b/Brussels.htm',
#    '../../wp/f/Finland.htm',
#    '../../wp/s/Suffrage.htm',
#    '../../wp/s/San_Marino.htm',
#    '../../wp/c/Christopher_Columbus.htm',
#    '../../wp/a/Atlantic_Ocean.htm',
#    '../../wp/v/Vatican_City.htm',
#    '../../wp/g/Germany.htm',
#    '../../wp/h/Hamburg.htm',
#    '../../wp/m/Munich.htm',
#    '../../wp/h/Hamburg.htm',
#    '../../wp/c/Cologne.htm',
#    '../../wp/d/Dresden.htm',
#    '../../wp/b/Berlin.htm',
#    '../../wp/c/Cathedral_of_Magdeburg.htm',
#    '../../wp/s/Sanssouci.htm',
#    '../../wp/u/United_States.htm'],
#   'abstract_length': 116,
#   'abstract_links': ['../../wp/h/History.htm'],
#   'categories_data': [{'name': 'Regulations and restrictions',
#     'num_words': 392,
#     'h2_links': ['../../wp/m/Monaco.htm',
#      '../../wp/v/Vatican_City.htm',
#      '../../wp/p/Pope_John_Paul_II.htm'],
#     'subcategories': []},
#    {'name': 'Issues',
#     'num_words': 3011,
#     'h2_links': ['../../wp/a/Austria.htm',
#      '../../wp/b/Belgium.htm',
#      '../../wp/f/Finland.htm',
#      '../../wp/g/Germany.htm',
#      '../../wp/g/Greece.htm',
#      '../../wp/i/Italy.htm',
#      '../../wp/l/Luxembourg.htm',
#      '../../wp/s/San_Marino.htm',
#      '../../wp/s/Spain.htm',
#      '../../wp/v/Vatican_City.htm',
#      '../../wp/f/France.htm',
#      '../../wp/i/Ireland.htm',
#      '../../wp/m/Monaco.htm',
#      '../../wp/n/Netherlands.htm',
#      '../../wp/p/Portugal.htm',
#      '../../wp/h/Heraldry.htm',
#      '../../wp/g/Greece.htm',
#      '../../wp/a/Athens.htm',
#      '../../wp/g/Greece.htm',
#      '../../wp/f/Finland.htm',
#      '../../wp/e/European_Union.htm',
#      '../../wp/l/Luxembourg.htm',
#      '../../wp/i/Italy.htm',
#      '../../wp/c/Cereal.htm',
#      '../../wp/m/Maize.htm',
#      '../../wp/r/Rice.htm',
#      '../../wp/w/Wheat.htm',
#      '../../wp/n/Nutrition.htm',
#      '../../wp/i/Italy.htm',
#      '../../wp/s/San_Marino.htm',
#      '../../wp/n/Numismatics.htm',
#      '../../wp/v/Vatican_City.htm',
#      '../../wp/l/Luxembourg.htm',
#      '../../wp/a/Austria.htm',
#      '../../wp/s/Soviet_Union.htm',
#      '../../wp/u/United_States.htm',
#      '../../wp/h/Harold_Macmillan.htm',
#      '../../wp/u/United_Kingdom.htm',
#      '../../wp/f/France.htm',
#      '../../wp/h/Heraldry.htm',
#      '../../wp/b/Belgium.htm',
#      '../../wp/s/Spain.htm',
#      '../../wp/m/Miguel_de_Cervantes.htm',
#      '../../wp/s/San_Marino.htm',
#      '../../wp/g/Galileo_Galilei.htm',
#      '../../wp/f/Finland.htm',
#      '../../wp/u/United_Nations.htm',
#      '../../wp/i/Italy.htm',
#      '../../wp/z/Zeus.htm',
#      '../../wp/v/Vatican_City.htm',
#      '../../wp/c/Cologne.htm',
#      '../../wp/c/Comet.htm',
#      '../../wp/l/Luxembourg.htm',
#      '../../wp/g/Germany.htm',
#      '../../wp/i/Italy.htm',
#      '../../wp/t/Turin.htm',
#      '../../wp/b/Belgium.htm',
#      '../../wp/b/Brussels.htm',
#      '../../wp/f/Finland.htm',
#      '../../wp/s/Suffrage.htm',
#      '../../wp/s/San_Marino.htm',
#      '../../wp/c/Christopher_Columbus.htm',
#      '../../wp/a/Atlantic_Ocean.htm',
#      '../../wp/v/Vatican_City.htm',
#      '../../wp/g/Germany.htm',
#      '../../wp/h/Hamburg.htm',
#      '../../wp/m/Munich.htm',
#      '../../wp/h/Hamburg.htm',
#      '../../wp/c/Cologne.htm',
#      '../../wp/d/Dresden.htm',
#      '../../wp/b/Berlin.htm',
#      '../../wp/c/Cathedral_of_Magdeburg.htm',
#      '../../wp/s/Sanssouci.htm',
#      '../../wp/u/United_States.htm'],
#     'subcategories': [{'name': '2004 coinage',
#       'num_words': 703,
#       'h3_links': ['../../wp/g/Greece.htm',
#        '../../wp/a/Athens.htm',
#        '../../wp/g/Greece.htm',
#        '../../wp/f/Finland.htm',
#        '../../wp/e/European_Union.htm',
#        '../../wp/l/Luxembourg.htm',
#        '../../wp/i/Italy.htm',
#        '../../wp/c/Cereal.htm',
#        '../../wp/m/Maize.htm',
#        '../../wp/r/Rice.htm',
#        '../../wp/w/Wheat.htm',
#        '../../wp/n/Nutrition.htm',
#        '../../wp/i/Italy.htm',
#        '../../wp/s/San_Marino.htm',
#        '../../wp/n/Numismatics.htm',
#        '../../wp/v/Vatican_City.htm']},
#      {'name': '2005 coinage',
#       'num_words': 979,
#       'h3_links': ['../../wp/l/Luxembourg.htm',
#        '../../wp/a/Austria.htm',
#        '../../wp/s/Soviet_Union.htm',
#        '../../wp/u/United_States.htm',
#        '../../wp/h/Harold_Macmillan.htm',
#        '../../wp/u/United_Kingdom.htm',
#        '../../wp/f/France.htm',
#        '../../wp/h/Heraldry.htm',
#        '../../wp/b/Belgium.htm',
#        '../../wp/s/Spain.htm',
#        '../../wp/m/Miguel_de_Cervantes.htm',
#        '../../wp/s/San_Marino.htm',
#        '../../wp/g/Galileo_Galilei.htm',
#        '../../wp/f/Finland.htm',
#        '../../wp/u/United_Nations.htm',
#        '../../wp/i/Italy.htm',
#        '../../wp/z/Zeus.htm',
#        '../../wp/v/Vatican_City.htm',
#        '../../wp/c/Cologne.htm',
#        '../../wp/c/Comet.htm']},
#      {'name': '2006 coinage',
#       'num_words': 737,
#       'h3_links': ['../../wp/l/Luxembourg.htm',
#        '../../wp/g/Germany.htm',
#        '../../wp/i/Italy.htm',
#        '../../wp/t/Turin.htm',
#        '../../wp/b/Belgium.htm',
#        '../../wp/b/Brussels.htm',
#        '../../wp/f/Finland.htm',
#        '../../wp/s/Suffrage.htm',
#        '../../wp/s/San_Marino.htm',
#        '../../wp/c/Christopher_Columbus.htm',
#        '../../wp/a/Atlantic_Ocean.htm',
#        '../../wp/v/Vatican_City.htm']},
#      {'name': '2007 coinage', 'num_words': 81, 'h3_links': []},
#      {'name': 'German Bundesländer series',
#       'num_words': 270,
#       'h3_links': ['../../wp/g/Germany.htm',
#        '../../wp/h/Hamburg.htm',
#        '../../wp/m/Munich.htm',
#        '../../wp/h/Hamburg.htm',
#        '../../wp/c/Cologne.htm',
#        '../../wp/d/Dresden.htm',
#        '../../wp/b/Berlin.htm',
#        '../../wp/c/Cathedral_of_Magdeburg.htm',
#        '../../wp/s/Sanssouci.htm',
#        '../../wp/u/United_States.htm']}]}],
#   'tables': [{'class': ['wikitable'],
#     'num_words': 703,
#     'table_links': ['../../wp/g/Greece.htm',
#      '../../wp/a/Athens.htm',
#      '../../wp/g/Greece.htm',
#      '../../wp/f/Finland.htm',
#      '../../wp/e/European_Union.htm',
#      '../../wp/l/Luxembourg.htm',
#      '../../wp/i/Italy.htm',
#      '../../wp/c/Cereal.htm',
#      '../../wp/m/Maize.htm',
#      '../../wp/r/Rice.htm',
#      '../../wp/w/Wheat.htm',
#      '../../wp/n/Nutrition.htm',
#      '../../wp/i/Italy.htm',
#      '../../wp/s/San_Marino.htm',
#      '../../wp/n/Numismatics.htm',
#      '../../wp/v/Vatican_City.htm']},
#    {'class': ['wikitable'],
#     'num_words': 979,
#     'table_links': ['../../wp/l/Luxembourg.htm',
#      '../../wp/a/Austria.htm',
#      '../../wp/s/Soviet_Union.htm',
#      '../../wp/u/United_States.htm',
#      '../../wp/h/Harold_Macmillan.htm',
#      '../../wp/u/United_Kingdom.htm',
#      '../../wp/f/France.htm',
#      '../../wp/h/Heraldry.htm',
#      '../../wp/b/Belgium.htm',
#      '../../wp/s/Spain.htm',
#      '../../wp/m/Miguel_de_Cervantes.htm',
#      '../../wp/s/San_Marino.htm',
#      '../../wp/g/Galileo_Galilei.htm',
#      '../../wp/f/Finland.htm',
#      '../../wp/u/United_Nations.htm',
#      '../../wp/i/Italy.htm',
#      '../../wp/z/Zeus.htm',
#      '../../wp/v/Vatican_City.htm',
#      '../../wp/c/Cologne.htm',
#      '../../wp/c/Comet.htm']},
#    {'class': ['wikitable'],
#     'num_words': 683,
#     'table_links': ['../../wp/l/Luxembourg.htm',
#      '../../wp/g/Germany.htm',
#      '../../wp/i/Italy.htm',
#      '../../wp/t/Turin.htm',
#      '../../wp/b/Belgium.htm',
#      '../../wp/b/Brussels.htm',
#      '../../wp/f/Finland.htm',
#      '../../wp/s/Suffrage.htm',
#      '../../wp/s/San_Marino.htm',
#      '../../wp/c/Christopher_Columbus.htm',
#      '../../wp/a/Atlantic_Ocean.htm']},
#    {'class': ['wikitable'], 'num_words': 10, 'table_links': []},
#    {'class': ['wikitable'],
#     'num_words': 110,
#     'table_links': ['../../wp/h/Hamburg.htm',
#      '../../wp/c/Cologne.htm',
#      '../../wp/d/Dresden.htm',
#      '../../wp/b/Berlin.htm',
#      '../../wp/c/Cathedral_of_Magdeburg.htm',
#      '../../wp/s/Sanssouci.htm']}]},
#  '10th century': {'title': '10th century',
#   'total_words': 849,
#   'total_links': ['../../wp/9/9th_century.htm',
#    '../../wp/1/11th_century.htm',
#    '../../wp/t/Time.htm',
#    '../../wp/d/Dark_Ages.htm',
#    '../../wp/i/India.htm',
#    '../../wp/v/Viking.htm',
#    '../../wp/f/France.htm',
#    '../../wp/g/Germany.htm',
#    '../../wp/i/Italy.htm',
#    '../../wp/f/France.htm',
#    '../../wp/p/Poland.htm',
#    '../../wp/k/Khazars.htm',
#    '../../wp/m/Maya_civilization.htm',
#    '../../wp/m/Mexico.htm',
#    '../../wp/g/Great_Moravia.htm',
#    '../../wp/m/Myanmar.htm',
#    '../../wp/p/Philippines.htm',
#    '../../wp/s/Solar_System.htm',
#    '../../wp/m/Monarchy.htm',
#    '../../wp/a/Algeria.htm',
#    '../../wp/s/Sweden.htm',
#    '../../wp/b/Black_Sea.htm',
#    '../../wp/b/Byzantine_Empire.htm',
#    '../../wp/d/Dublin.htm',
#    '../../wp/s/Scotland.htm',
#    '../../wp/l/Lion.htm',
#    '../../wp/b/Byzantine_Empire.htm',
#    '../../wp/b/Byzantine_Empire.htm',
#    '../../wp/b/Byzantine_Empire.htm',
#    '../../wp/b/Beer.htm'],
#   'abstract_length': 76,
#   'abstract_links': ['../../wp/9/9th_century.htm',
#    '../../wp/1/11th_century.htm',
#    '../../wp/t/Time.htm'],
#   'categories_data': [{'name': 'Overview',
#     'num_words': 119,
#     'h2_links': ['../../wp/d/Dark_Ages.htm'],
#     'subcategories': []},
#    {'name': 'Events',
#     'num_words': 290,
#     'h2_links': ['../../wp/i/India.htm',
#      '../../wp/v/Viking.htm',
#      '../../wp/f/France.htm',
#      '../../wp/g/Germany.htm',
#      '../../wp/i/Italy.htm',
#      '../../wp/f/France.htm',
#      '../../wp/p/Poland.htm',
#      '../../wp/k/Khazars.htm',
#      '../../wp/m/Maya_civilization.htm',
#      '../../wp/m/Mexico.htm',
#      '../../wp/g/Great_Moravia.htm',
#      '../../wp/m/Myanmar.htm',
#      '../../wp/p/Philippines.htm',
#      '../../wp/s/Solar_System.htm',
#      '../../wp/m/Monarchy.htm',
#      '../../wp/a/Algeria.htm',
#      '../../wp/s/Sweden.htm',
#      '../../wp/b/Black_Sea.htm',
#      '../../wp/b/Byzantine_Empire.htm',
#      '../../wp/d/Dublin.htm',
#      '../../wp/s/Scotland.htm',
#      '../../wp/l/Lion.htm'],
#     'subcategories': []},
#    {'name': 'Significant people',
#     'num_words': 209,
#     'h2_links': ['../../wp/b/Byzantine_Empire.htm',
#      '../../wp/b/Byzantine_Empire.htm',
#      '../../wp/b/Byzantine_Empire.htm'],
#     'subcategories': []},
#    {'name': 'Inventions, discoveries, introductions',
#     'num_words': 9,
#     'h2_links': ['../../wp/b/Beer.htm'],
#     'subcategories': []},
#    {'name': 'Decades and years',
#     'num_words': 136,
#     'h2_links': [],
#     'subcategories': []}],
#   'tables': [{'class': ['infobox'], 'num_words': 10, 'table_links': []},
#    {'class': ['infobox'],
#     'num_words': 20,
#     'table_links': ['../../wp/9/9th_century.htm',
#      '../../wp/1/11th_century.htm']},
#    {'class': None, 'num_words': 132, 'table_links': []}]},
#  '11th century': {'title': '11th century',
#   'total_words': 1163,
#   'total_links': ['../../wp/1/10th_century.htm',
#    '../../wp/1/12th_century.htm',
#    '../../wp/t/Time.htm',
#    '../../wp/d/Dark_Ages.htm',
#    '../../wp/c/Crusades.htm',
#    '../../wp/b/Byzantine_Empire.htm',
#    '../../wp/n/Norman_conquest_of_England.htm',
#    '../../wp/b/Battle_of_Hastings.htm',
#    '../../wp/i/India.htm',
#    '../../wp/v/Viking.htm',
#    '../../wp/l/Leif_Ericson.htm',
#    '../../wp/n/North_America.htm',
#    '../../wp/m/Macbeth_of_Scotland.htm',
#    '../../wp/e/East-West_Schism.htm',
#    '../../wp/p/Portugal.htm',
#    '../../wp/e/Edward_the_Confessor.htm',
#    '../../wp/e/England.htm',
#    '../../wp/b/Battle_of_Hastings.htm',
#    '../../wp/b/Byzantine_Empire.htm',
#    '../../wp/g/Ghana.htm',
#    '../../wp/d/Domesday_Book.htm',
#    '../../wp/f/First_Crusade.htm',
#    '../../wp/j/Jerusalem.htm',
#    '../../wp/m/Myanmar.htm',
#    '../../wp/n/Nigeria.htm',
#    '../../wp/n/Nigeria.htm',
#    '../../wp/m/Mauritania.htm',
#    '../../wp/c/Canute_the_Great.htm',
#    '../../wp/l/Leif_Ericson.htm',
#    '../../wp/w/William_I_of_England.htm',
#    '../../wp/f/France.htm',
#    '../../wp/c/China.htm',
#    '../../wp/n/Novel.htm',
#    '../../wp/1/1st_century_BC.htm',
#    '../../wp/1/1st_century.htm',
#    '../../wp/2/2nd_century.htm',
#    '../../wp/3/3rd_century.htm',
#    '../../wp/4/4th_century.htm',
#    '../../wp/5/5th_century.htm',
#    '../../wp/6/6th_century.htm',
#    '../../wp/7/7th_century.htm',
#    '../../wp/8/8th_century.htm',
#    '../../wp/9/9th_century.htm',
#    '../../wp/1/10th_century.htm',
#    '../../wp/1/12th_century.htm',
#    '../../wp/1/13th_century.htm',
#    '../../wp/1/14th_century.htm',
#    '../../wp/1/15th_century.htm',
#    '../../wp/1/16th_century.htm',
#    '../../wp/1/17th_century.htm',
#    '../../wp/1/18th_century.htm',
#    '../../wp/1/19th_century.htm',
#    '../../wp/2/20th_century.htm',
#    '../../wp/2/21st_century.htm'],
#   'abstract_length': 93,
#   'abstract_links': ['../../wp/1/10th_century.htm',
#    '../../wp/1/12th_century.htm',
#    '../../wp/t/Time.htm'],
#   'categories_data': [{'name': 'Overview',
#     'num_words': 351,
#     'h2_links': ['../../wp/d/Dark_Ages.htm',
#      '../../wp/c/Crusades.htm',
#      '../../wp/b/Byzantine_Empire.htm',
#      '../../wp/n/Norman_conquest_of_England.htm'],
#     'subcategories': []},
#    {'name': 'Events',
#     'num_words': 289,
#     'h2_links': ['../../wp/b/Battle_of_Hastings.htm',
#      '../../wp/i/India.htm',
#      '../../wp/v/Viking.htm',
#      '../../wp/l/Leif_Ericson.htm',
#      '../../wp/n/North_America.htm',
#      '../../wp/m/Macbeth_of_Scotland.htm',
#      '../../wp/e/East-West_Schism.htm',
#      '../../wp/p/Portugal.htm',
#      '../../wp/e/Edward_the_Confessor.htm',
#      '../../wp/e/England.htm',
#      '../../wp/b/Battle_of_Hastings.htm',
#      '../../wp/b/Byzantine_Empire.htm',
#      '../../wp/g/Ghana.htm',
#      '../../wp/d/Domesday_Book.htm',
#      '../../wp/f/First_Crusade.htm',
#      '../../wp/j/Jerusalem.htm',
#      '../../wp/m/Myanmar.htm',
#      '../../wp/n/Nigeria.htm',
#      '../../wp/n/Nigeria.htm',
#      '../../wp/m/Mauritania.htm'],
#     'subcategories': []},
#    {'name': 'Significant people',
#     'num_words': 99,
#     'h2_links': ['../../wp/c/Canute_the_Great.htm',
#      '../../wp/l/Leif_Ericson.htm',
#      '../../wp/w/William_I_of_England.htm'],
#     'subcategories': []},
#    {'name': 'Inventions, discoveries, introductions',
#     'num_words': 43,
#     'h2_links': ['../../wp/f/France.htm',
#      '../../wp/c/China.htm',
#      '../../wp/n/Novel.htm'],
#     'subcategories': []},
#    {'name': 'Decades and years',
#     'num_words': 278,
#     'h2_links': ['../../wp/1/1st_century_BC.htm',
#      '../../wp/1/1st_century.htm',
#      '../../wp/2/2nd_century.htm',
#      '../../wp/3/3rd_century.htm',
#      '../../wp/4/4th_century.htm',
#      '../../wp/5/5th_century.htm',
#      '../../wp/6/6th_century.htm',
#      '../../wp/7/7th_century.htm',
#      '../../wp/8/8th_century.htm',
#      '../../wp/9/9th_century.htm',
#      '../../wp/1/10th_century.htm',
#      '../../wp/1/12th_century.htm',
#      '../../wp/1/13th_century.htm',
#      '../../wp/1/14th_century.htm',
#      '../../wp/1/15th_century.htm',
#      '../../wp/1/16th_century.htm',
#      '../../wp/1/17th_century.htm',
#      '../../wp/1/18th_century.htm',
#      '../../wp/1/19th_century.htm',
#      '../../wp/2/20th_century.htm',
#      '../../wp/2/21st_century.htm'],
#     'subcategories': []}],
#   'tables': [{'class': ['infobox'], 'num_words': 9, 'table_links': []},
#    {'class': ['infobox'],
#     'num_words': 20,
#     'table_links': ['../../wp/1/10th_century.htm',
#      '../../wp/1/12th_century.htm']},
#    {'class': None, 'num_words': 132, 'table_links': []},
#    {'class': None,
#     'num_words': 142,
#     'table_links': ['../../wp/1/1st_century_BC.htm',
#      '../../wp/1/1st_century.htm',
#      '../../wp/2/2nd_century.htm',
#      '../../wp/3/3rd_century.htm',
#      '../../wp/4/4th_century.htm',
#      '../../wp/5/5th_century.htm',
#      '../../wp/6/6th_century.htm',
#      '../../wp/7/7th_century.htm',
#      '../../wp/8/8th_century.htm',
#      '../../wp/9/9th_century.htm',
#      '../../wp/1/10th_century.htm',
#      '../../wp/1/12th_century.htm',
#      '../../wp/1/13th_century.htm',
#      '../../wp/1/14th_century.htm',
#      '../../wp/1/15th_century.htm',
#      '../../wp/1/16th_century.htm',
#      '../../wp/1/17th_century.htm',
#      '../../wp/1/18th_century.htm',
#      '../../wp/1/19th_century.htm',
#      '../../wp/2/20th_century.htm',
#      '../../wp/2/21st_century.htm']}]},
#  '12th century': {'title': '12th century',
#   'total_words': 971,
#   'total_links': ['../../wp/1/11th_century.htm',
#    '../../wp/1/13th_century.htm',
#    '../../wp/t/Time.htm',
#    '../../wp/h/Hungary.htm',
#    '../../wp/c/Croatia.htm',
#    '../../wp/p/Portugal.htm',
#    '../../wp/t/The_Anarchy.htm',
#    '../../wp/e/England.htm',
#    '../../wp/p/Paris.htm',
#    '../../wp/s/Second_Crusade.htm',
#    '../../wp/t/Thomas_Becket.htm',
#    '../../wp/s/Sweden.htm',
#    '../../wp/s/Saladin.htm',
#    '../../wp/i/India.htm',
#    '../../wp/f/Frederick_II%252C_Holy_Roman_Emperor.htm',
#    '../../wp/f/France.htm',
#    '../../wp/a/Angkor_Wat.htm',
#    '../../wp/i/Ireland.htm',
#    '../../wp/h/Henry_II_of_England.htm',
#    '../../wp/s/Serbia.htm',
#    '../../wp/f/Francis_of_Assisi.htm',
#    '../../wp/g/Genghis_Khan.htm',
#    '../../wp/m/Mongol_Empire.htm',
#    '../../wp/s/Saladin.htm',
#    '../../wp/r/Richard_I_of_England.htm',
#    '../../wp/t/Thomas_Becket.htm',
#    '../../wp/i/Iran.htm',
#    '../../wp/f/France.htm',
#    '../../wp/f/France.htm',
#    '../../wp/a/Angkor_Wat.htm',
#    '../../wp/f/France.htm',
#    '../../wp/i/Iceland.htm',
#    '../../wp/1/1st_century_BC.htm',
#    '../../wp/1/1st_century.htm',
#    '../../wp/2/2nd_century.htm',
#    '../../wp/3/3rd_century.htm',
#    '../../wp/4/4th_century.htm',
#    '../../wp/5/5th_century.htm',
#    '../../wp/6/6th_century.htm',
#    '../../wp/7/7th_century.htm',
#    '../../wp/8/8th_century.htm',
#    '../../wp/9/9th_century.htm',
#    '../../wp/1/10th_century.htm',
#    '../../wp/1/11th_century.htm',
#    '../../wp/1/13th_century.htm',
#    '../../wp/1/14th_century.htm',
#    '../../wp/1/15th_century.htm',
#    '../../wp/1/16th_century.htm',
#    '../../wp/1/17th_century.htm',
#    '../../wp/1/18th_century.htm',
#    '../../wp/1/19th_century.htm',
#    '../../wp/2/20th_century.htm',
#    '../../wp/2/21st_century.htm'],
#   'abstract_length': 98,
#   'abstract_links': ['../../wp/1/11th_century.htm',
#    '../../wp/1/13th_century.htm',
#    '../../wp/t/Time.htm'],
#   'categories_data': [{'name': 'Events',
#     'num_words': 317,
#     'h2_links': ['../../wp/h/Hungary.htm',
#      '../../wp/c/Croatia.htm',
#      '../../wp/p/Portugal.htm',
#      '../../wp/t/The_Anarchy.htm',
#      '../../wp/e/England.htm',
#      '../../wp/p/Paris.htm',
#      '../../wp/s/Second_Crusade.htm',
#      '../../wp/t/Thomas_Becket.htm',
#      '../../wp/s/Sweden.htm',
#      '../../wp/s/Saladin.htm',
#      '../../wp/i/India.htm',
#      '../../wp/f/Frederick_II%252C_Holy_Roman_Emperor.htm',
#      '../../wp/f/France.htm',
#      '../../wp/a/Angkor_Wat.htm',
#      '../../wp/i/Ireland.htm',
#      '../../wp/h/Henry_II_of_England.htm',
#      '../../wp/s/Serbia.htm'],
#     'subcategories': []},
#    {'name': 'Significant people',
#     'num_words': 175,
#     'h2_links': ['../../wp/f/Francis_of_Assisi.htm',
#      '../../wp/g/Genghis_Khan.htm',
#      '../../wp/m/Mongol_Empire.htm',
#      '../../wp/s/Saladin.htm',
#      '../../wp/r/Richard_I_of_England.htm',
#      '../../wp/t/Thomas_Becket.htm',
#      '../../wp/i/Iran.htm',
#      '../../wp/f/France.htm'],
#     'subcategories': []},
#    {'name': 'Inventions, discoveries and introductions',
#     'num_words': 93,
#     'h2_links': ['../../wp/f/France.htm',
#      '../../wp/a/Angkor_Wat.htm',
#      '../../wp/f/France.htm',
#      '../../wp/i/Iceland.htm'],
#     'subcategories': []},
#    {'name': 'Decades and years',
#     'num_words': 278,
#     'h2_links': ['../../wp/1/1st_century_BC.htm',
#      '../../wp/1/1st_century.htm',
#      '../../wp/2/2nd_century.htm',
#      '../../wp/3/3rd_century.htm',
#      '../../wp/4/4th_century.htm',
#      '../../wp/5/5th_century.htm',
#      '../../wp/6/6th_century.htm',
#      '../../wp/7/7th_century.htm',
#      '../../wp/8/8th_century.htm',
#      '../../wp/9/9th_century.htm',
#      '../../wp/1/10th_century.htm',
#      '../../wp/1/11th_century.htm',
#      '../../wp/1/13th_century.htm',
#      '../../wp/1/14th_century.htm',
#      '../../wp/1/15th_century.htm',
#      '../../wp/1/16th_century.htm',
#      '../../wp/1/17th_century.htm',
#      '../../wp/1/18th_century.htm',
#      '../../wp/1/19th_century.htm',
#      '../../wp/2/20th_century.htm',
#      '../../wp/2/21st_century.htm'],
#     'subcategories': []}],
#   'tables': [{'class': ['infobox'], 'num_words': 9, 'table_links': []},
#    {'class': ['infobox'],
#     'num_words': 20,
#     'table_links': ['../../wp/1/11th_century.htm',
#      '../../wp/1/13th_century.htm']},
#    {'class': None, 'num_words': 132, 'table_links': []},
#    {'class': None,
#     'num_words': 142,
#     'table_links': ['../../wp/1/1st_century_BC.htm',
#      '../../wp/1/1st_century.htm',
#      '../../wp/2/2nd_century.htm',
#      '../../wp/3/3rd_century.htm',
#      '../../wp/4/4th_century.htm',
#      '../../wp/5/5th_century.htm',
#      '../../wp/6/6th_century.htm',
#      '../../wp/7/7th_century.htm',
#      '../../wp/8/8th_century.htm',
#      '../../wp/9/9th_century.htm',
#      '../../wp/1/10th_century.htm',
#      '../../wp/1/11th_century.htm',
#      '../../wp/1/13th_century.htm',
#      '../../wp/1/14th_century.htm',
#      '../../wp/1/15th_century.htm',
#      '../../wp/1/16th_century.htm',
#      '../../wp/1/17th_century.htm',
#      '../../wp/1/18th_century.htm',
#      '../../wp/1/19th_century.htm',
#      '../../wp/2/20th_century.htm',
#      '../../wp/2/21st_century.htm']}]},
#  '13th century': {'title': '13th century',
#   'total_words': 810,
#   'total_links': ['../../wp/1/12th_century.htm',
#    '../../wp/1/14th_century.htm',
#    '../../wp/t/Time.htm',
#    '../../wp/g/Genghis_Khan.htm',
#    '../../wp/a/Asia.htm',
#    '../../wp/g/Genghis_Khan.htm',
#    '../../wp/m/Mongol_Empire.htm',
#    '../../wp/c/China.htm',
#    '../../wp/i/Islam.htm',
#    '../../wp/b/Byzantine_Empire.htm',
#    '../../wp/i/Islam.htm',
#    '../../wp/j/John_of_England.htm',
#    '../../wp/m/Magna_Carta.htm',
#    '../../wp/m/Marco_Polo.htm',
#    '../../wp/c/China.htm',
#    '../../wp/h/Hungary.htm',
#    '../../wp/b/Buddhism.htm',
#    '../../wp/c/Cambodia.htm',
#    '../../wp/i/Iran.htm',
#    '../../wp/a/Arabic_language.htm',
#    '../../wp/t/Thailand.htm',
#    '../../wp/t/Thailand.htm',
#    '../../wp/l/Laos.htm',
#    '../../wp/m/Myanmar.htm',
#    '../../wp/m/Malaysia.htm',
#    '../../wp/n/Norway.htm',
#    '../../wp/i/Isle_of_Man.htm',
#    '../../wp/s/Scotland.htm',
#    '../../wp/e/Europe.htm',
#    '../../wp/b/Bantu.htm',
#    '../../wp/a/Angola.htm',
#    '../../wp/i/Iceland.htm',
#    '../../wp/h/Hungary.htm',
#    '../../wp/s/Stockholm.htm',
#    '../../wp/d/Dante_Alighieri.htm',
#    '../../wp/f/Francis_of_Assisi.htm',
#    '../../wp/f/Frederick_II%252C_Holy_Roman_Emperor.htm',
#    '../../wp/h/Holy_Roman_Empire.htm',
#    '../../wp/g/Genghis_Khan.htm',
#    '../../wp/m/Mongol_Empire.htm',
#    '../../wp/c/China.htm',
#    '../../wp/t/Thomas_Aquinas.htm'],
#   'abstract_length': 133,
#   'abstract_links': ['../../wp/1/12th_century.htm',
#    '../../wp/1/14th_century.htm',
#    '../../wp/t/Time.htm',
#    '../../wp/g/Genghis_Khan.htm',
#    '../../wp/a/Asia.htm'],
#   'categories_data': [{'name': 'Events',
#     'num_words': 353,
#     'h2_links': ['../../wp/g/Genghis_Khan.htm',
#      '../../wp/m/Mongol_Empire.htm',
#      '../../wp/c/China.htm',
#      '../../wp/i/Islam.htm',
#      '../../wp/b/Byzantine_Empire.htm',
#      '../../wp/i/Islam.htm',
#      '../../wp/j/John_of_England.htm',
#      '../../wp/m/Magna_Carta.htm',
#      '../../wp/m/Marco_Polo.htm',
#      '../../wp/c/China.htm',
#      '../../wp/h/Hungary.htm',
#      '../../wp/b/Buddhism.htm',
#      '../../wp/c/Cambodia.htm',
#      '../../wp/i/Iran.htm',
#      '../../wp/a/Arabic_language.htm',
#      '../../wp/t/Thailand.htm',
#      '../../wp/t/Thailand.htm',
#      '../../wp/l/Laos.htm',
#      '../../wp/m/Myanmar.htm',
#      '../../wp/m/Malaysia.htm',
#      '../../wp/n/Norway.htm',
#      '../../wp/i/Isle_of_Man.htm',
#      '../../wp/s/Scotland.htm',
#      '../../wp/e/Europe.htm',
#      '../../wp/b/Bantu.htm',
#      '../../wp/a/Angola.htm',
#      '../../wp/i/Iceland.htm'],
#     'subcategories': []},
#    {'name': 'Significant people',
#     'num_words': 160,
#     'h2_links': ['../../wp/h/Hungary.htm',
#      '../../wp/s/Stockholm.htm',
#      '../../wp/d/Dante_Alighieri.htm',
#      '../../wp/f/Francis_of_Assisi.htm',
#      '../../wp/f/Frederick_II%252C_Holy_Roman_Emperor.htm',
#      '../../wp/h/Holy_Roman_Empire.htm',
#      '../../wp/g/Genghis_Khan.htm',
#      '../../wp/m/Mongol_Empire.htm',
#      '../../wp/c/China.htm',
#      '../../wp/t/Thomas_Aquinas.htm'],
#     'subcategories': []},
#    {'name': 'Inventions, discoveries, introductions',
#     'num_words': 19,
#     'h2_links': [],
#     'subcategories': []},
#    {'name': 'Decades and years',
#     'num_words': 136,
#     'h2_links': [],
#     'subcategories': []}],
#   'tables': [{'class': ['infobox'], 'num_words': 9, 'table_links': []},
#    {'class': ['infobox'],
#     'num_words': 20,
#     'table_links': ['../../wp/1/12th_century.htm',
#      '../../wp/1/14th_century.htm']},
#    {'class': None, 'num_words': 132, 'table_links': []}]},
#  '14th century': {'title': '14th century',
#   'total_words': 841,
#   'total_links': ['../../wp/1/13th_century.htm',
#    '../../wp/1/15th_century.htm',
#    '../../wp/i/India.htm',
#    '../../wp/w/Washington%252C_D.C..htm',
#    '../../wp/t/Time.htm',
#    '../../wp/o/Ottoman_Empire.htm',
#    '../../wp/i/Italy.htm',
#    '../../wp/f/France.htm',
#    '../../wp/e/Europe.htm',
#    '../../wp/a/Aztec.htm',
#    '../../wp/h/Hundred_Years%2527_War.htm',
#    '../../wp/e/Edward_III_of_England.htm',
#    '../../wp/e/England.htm',
#    '../../wp/f/France.htm',
#    '../../wp/b/Black_Death.htm',
#    '../../wp/c/China.htm',
#    '../../wp/m/Ming_Dynasty.htm',
#    '../../wp/e/England.htm',
#    '../../wp/p/Pope.htm',
#    '../../wp/b/Buddha.htm',
#    '../../wp/c/Christianity.htm',
#    '../../wp/s/Singapore.htm',
#    '../../wp/p/Poland.htm',
#    '../../wp/e/English_peasants%2527_revolt_of_1381.htm',
#    '../../wp/i/Islam.htm',
#    '../../wp/n/Niger.htm',
#    '../../wp/d/Dark_Ages.htm',
#    '../../wp/e/Europe.htm',
#    '../../wp/r/Renaissance.htm',
#    '../../wp/p/Poland.htm',
#    '../../wp/l/Lithuania.htm',
#    '../../wp/r/Renaissance.htm',
#    '../../wp/a/Abacus.htm',
#    '../../wp/c/China.htm',
#    '../../wp/d/Dante_Alighieri.htm',
#    '../../wp/i/Ibn_Battuta.htm',
#    '../../wp/e/Edward_III_of_England.htm',
#    '../../wp/h/Hundred_Years%2527_War.htm',
#    '../../wp/t/Timur.htm'],
#   'abstract_length': 104,
#   'abstract_links': ['../../wp/1/13th_century.htm',
#    '../../wp/1/15th_century.htm',
#    '../../wp/i/India.htm',
#    '../../wp/w/Washington%252C_D.C..htm',
#    '../../wp/t/Time.htm'],
#   'categories_data': [{'name': 'Events',
#     'num_words': 341,
#     'h2_links': ['../../wp/o/Ottoman_Empire.htm',
#      '../../wp/i/Italy.htm',
#      '../../wp/f/France.htm',
#      '../../wp/e/Europe.htm',
#      '../../wp/a/Aztec.htm',
#      '../../wp/h/Hundred_Years%2527_War.htm',
#      '../../wp/e/Edward_III_of_England.htm',
#      '../../wp/e/England.htm',
#      '../../wp/f/France.htm',
#      '../../wp/b/Black_Death.htm',
#      '../../wp/c/China.htm',
#      '../../wp/m/Ming_Dynasty.htm',
#      '../../wp/e/England.htm',
#      '../../wp/p/Pope.htm',
#      '../../wp/b/Buddha.htm',
#      '../../wp/c/Christianity.htm',
#      '../../wp/s/Singapore.htm',
#      '../../wp/p/Poland.htm',
#      '../../wp/e/English_peasants%2527_revolt_of_1381.htm',
#      '../../wp/i/Islam.htm',
#      '../../wp/n/Niger.htm',
#      '../../wp/d/Dark_Ages.htm',
#      '../../wp/e/Europe.htm',
#      '../../wp/r/Renaissance.htm',
#      '../../wp/p/Poland.htm',
#      '../../wp/l/Lithuania.htm',
#      '../../wp/r/Renaissance.htm',
#      '../../wp/a/Abacus.htm',
#      '../../wp/c/China.htm'],
#     'subcategories': []},
#    {'name': 'Significant people',
#     'num_words': 236,
#     'h2_links': ['../../wp/d/Dante_Alighieri.htm',
#      '../../wp/i/Ibn_Battuta.htm',
#      '../../wp/e/Edward_III_of_England.htm',
#      '../../wp/h/Hundred_Years%2527_War.htm',
#      '../../wp/t/Timur.htm'],
#     'subcategories': []},
#    {'name': 'Inventions, discoveries, introductions',
#     'num_words': 15,
#     'h2_links': [],
#     'subcategories': []},
#    {'name': 'Decades and years',
#     'num_words': 136,
#     'h2_links': [],
#     'subcategories': []}],
#   'tables': [{'class': ['infobox'], 'num_words': 9, 'table_links': []},
#    {'class': ['infobox'],
#     'num_words': 20,
#     'table_links': ['../../wp/1/13th_century.htm',
#      '../../wp/1/15th_century.htm']},
#    {'class': None, 'num_words': 132, 'table_links': []}]},
#  '15th century': {'title': '15th century',
#   'total_words': 1302,
#   'total_links': ['../../wp/1/14th_century.htm',
#    '../../wp/1/16th_century.htm',
#    '../../wp/t/Time.htm',
#    '../../wp/t/Timur.htm',
#    '../../wp/b/Baghdad.htm',
#    '../../wp/o/Ottoman_Empire.htm',
#    '../../wp/b/Beijing.htm',
#    '../../wp/z/Zheng_He.htm',
#    '../../wp/i/Indian_Ocean.htm',
#    '../../wp/b/Battle_of_Grunwald.htm',
#    '../../wp/f/France.htm',
#    '../../wp/j/Joan_of_Arc.htm',
#    '../../wp/h/Hundred_Years%2527_War.htm',
#    '../../wp/i/Inca_Empire.htm',
#    '../../wp/a/Aztec.htm',
#    '../../wp/b/Byzantine_Empire.htm',
#    '../../wp/h/Hundred_Years%2527_War.htm',
#    '../../wp/w/Wars_of_the_Roses.htm',
#    '../../wp/s/Spain.htm',
#    '../../wp/f/France.htm',
#    '../../wp/s/Spanish_Inquisition.htm',
#    '../../wp/j/Jew.htm',
#    '../../wp/s/Spain.htm',
#    '../../wp/c/Christopher_Columbus.htm',
#    '../../wp/v/Vasco_da_Gama.htm',
#    '../../wp/e/Europe.htm',
#    '../../wp/i/India.htm',
#    '../../wp/z/Zheng_He.htm',
#    '../../wp/h/Henry_V_of_England.htm',
#    '../../wp/j/Johannes_Ockeghem.htm',
#    '../../wp/j/Joan_of_Arc.htm',
#    '../../wp/f/France.htm',
#    '../../wp/p/Poland.htm',
#    '../../wp/l/Lithuania.htm',
#    '../../wp/o/Ottoman_Empire.htm',
#    '../../wp/o/Ottoman_Empire.htm',
#    '../../wp/p/Plato.htm',
#    '../../wp/c/Christopher_Columbus.htm',
#    '../../wp/s/Spain.htm',
#    '../../wp/r/Richard_III_of_England.htm',
#    '../../wp/l/Leonardo_da_Vinci.htm',
#    '../../wp/h/Henry_VII_of_England.htm',
#    '../../wp/v/Vasco_da_Gama.htm',
#    '../../wp/p/Portugal.htm',
#    '../../wp/r/Renaissance.htm',
#    '../../wp/p/Philosophy.htm',
#    '../../wp/a/Art.htm',
#    '../../wp/k/Korea.htm',
#    '../../wp/k/Korea.htm',
#    '../../wp/n/North_America.htm',
#    '../../wp/c/Christopher_Columbus.htm',
#    '../../wp/1/1st_century_BC.htm',
#    '../../wp/1/1st_century.htm',
#    '../../wp/2/2nd_century.htm',
#    '../../wp/3/3rd_century.htm',
#    '../../wp/4/4th_century.htm',
#    '../../wp/5/5th_century.htm',
#    '../../wp/6/6th_century.htm',
#    '../../wp/7/7th_century.htm',
#    '../../wp/8/8th_century.htm',
#    '../../wp/9/9th_century.htm',
#    '../../wp/1/10th_century.htm',
#    '../../wp/1/11th_century.htm',
#    '../../wp/1/12th_century.htm',
#    '../../wp/1/13th_century.htm',
#    '../../wp/1/14th_century.htm',
#    '../../wp/1/16th_century.htm',
#    '../../wp/1/17th_century.htm',
#    '../../wp/1/18th_century.htm',
#    '../../wp/1/19th_century.htm',
#    '../../wp/2/20th_century.htm',
#    '../../wp/2/21st_century.htm'],
#   'abstract_length': 75,
#   'abstract_links': ['../../wp/1/14th_century.htm',
#    '../../wp/1/16th_century.htm',
#    '../../wp/t/Time.htm'],
#   'categories_data': [{'name': 'Events',
#     'num_words': 430,
#     'h2_links': ['../../wp/t/Timur.htm',
#      '../../wp/b/Baghdad.htm',
#      '../../wp/o/Ottoman_Empire.htm',
#      '../../wp/b/Beijing.htm',
#      '../../wp/z/Zheng_He.htm',
#      '../../wp/i/Indian_Ocean.htm',
#      '../../wp/b/Battle_of_Grunwald.htm',
#      '../../wp/f/France.htm',
#      '../../wp/j/Joan_of_Arc.htm',
#      '../../wp/h/Hundred_Years%2527_War.htm',
#      '../../wp/i/Inca_Empire.htm',
#      '../../wp/a/Aztec.htm',
#      '../../wp/b/Byzantine_Empire.htm',
#      '../../wp/h/Hundred_Years%2527_War.htm',
#      '../../wp/w/Wars_of_the_Roses.htm',
#      '../../wp/s/Spain.htm',
#      '../../wp/f/France.htm',
#      '../../wp/s/Spanish_Inquisition.htm',
#      '../../wp/j/Jew.htm',
#      '../../wp/s/Spain.htm',
#      '../../wp/c/Christopher_Columbus.htm',
#      '../../wp/v/Vasco_da_Gama.htm',
#      '../../wp/e/Europe.htm',
#      '../../wp/i/India.htm'],
#     'subcategories': []},
#    {'name': 'Significant people',
#     'num_words': 376,
#     'h2_links': ['../../wp/z/Zheng_He.htm',
#      '../../wp/h/Henry_V_of_England.htm',
#      '../../wp/j/Johannes_Ockeghem.htm',
#      '../../wp/j/Joan_of_Arc.htm',
#      '../../wp/f/France.htm',
#      '../../wp/p/Poland.htm',
#      '../../wp/l/Lithuania.htm',
#      '../../wp/o/Ottoman_Empire.htm',
#      '../../wp/o/Ottoman_Empire.htm',
#      '../../wp/p/Plato.htm',
#      '../../wp/c/Christopher_Columbus.htm',
#      '../../wp/s/Spain.htm',
#      '../../wp/r/Richard_III_of_England.htm',
#      '../../wp/l/Leonardo_da_Vinci.htm',
#      '../../wp/h/Henry_VII_of_England.htm',
#      '../../wp/v/Vasco_da_Gama.htm',
#      '../../wp/p/Portugal.htm'],
#     'subcategories': []},
#    {'name': 'Inventions, discoveries, introductions',
#     'num_words': 134,
#     'h2_links': ['../../wp/r/Renaissance.htm',
#      '../../wp/p/Philosophy.htm',
#      '../../wp/a/Art.htm',
#      '../../wp/k/Korea.htm',
#      '../../wp/k/Korea.htm',
#      '../../wp/n/North_America.htm',
#      '../../wp/c/Christopher_Columbus.htm'],
#     'subcategories': []},
#    {'name': 'Decades and years',
#     'num_words': 278,
#     'h2_links': ['../../wp/1/1st_century_BC.htm',
#      '../../wp/1/1st_century.htm',
#      '../../wp/2/2nd_century.htm',
#      '../../wp/3/3rd_century.htm',
#      '../../wp/4/4th_century.htm',
#      '../../wp/5/5th_century.htm',
#      '../../wp/6/6th_century.htm',
#      '../../wp/7/7th_century.htm',
#      '../../wp/8/8th_century.htm',
#      '../../wp/9/9th_century.htm',
#      '../../wp/1/10th_century.htm',
#      '../../wp/1/11th_century.htm',
#      '../../wp/1/12th_century.htm',
#      '../../wp/1/13th_century.htm',
#      '../../wp/1/14th_century.htm',
#      '../../wp/1/16th_century.htm',
#      '../../wp/1/17th_century.htm',
#      '../../wp/1/18th_century.htm',
#      '../../wp/1/19th_century.htm',
#      '../../wp/2/20th_century.htm',
#      '../../wp/2/21st_century.htm'],
#     'subcategories': []}],
#   'tables': [{'class': ['infobox'], 'num_words': 9, 'table_links': []},
#    {'class': ['infobox'],
#     'num_words': 20,
#     'table_links': ['../../wp/1/14th_century.htm',
#      '../../wp/1/16th_century.htm']},
#    {'class': None, 'num_words': 132, 'table_links': []},
#    {'class': None,
#     'num_words': 142,
#     'table_links': ['../../wp/1/1st_century_BC.htm',
#      '../../wp/1/1st_century.htm',
#      '../../wp/2/2nd_century.htm',
#      '../../wp/3/3rd_century.htm',
#      '../../wp/4/4th_century.htm',
#      '../../wp/5/5th_century.htm',
#      '../../wp/6/6th_century.htm',
#      '../../wp/7/7th_century.htm',
#      '../../wp/8/8th_century.htm',
# ...
#      '../../wp/e/Ethanol.htm',
#      '../../wp/c/Carbon_dioxide.htm',
#      '../../wp/i/Iron%2528III%2529_chloride.htm'],
#     'subcategories': []},
#    {'name': 'Biochemistry',
#     'num_words': 165,
#     'h2_links': ['../../wp/b/Bacteria.htm',
#      '../../wp/f/Food.htm',
#      '../../wp/w/Water.htm',
#      '../../wp/s/Soil.htm'],
#     'subcategories': []},
#    {'name': 'Production',
#     'num_words': 1324,
#     'h2_links': ['../../wp/u/United_States.htm',
#      '../../wp/e/Europe.htm',
#      '../../wp/j/Japan.htm',
#      '../../wp/b/BP.htm',
#      '../../wp/c/Cobalt.htm',
#      '../../wp/r/Rhodium.htm',
#      '../../wp/b/BP.htm',
#      '../../wp/r/Ruthenium.htm',
#      '../../wp/i/Iridium.htm',
#      '../../wp/m/Manganese.htm',
#      '../../wp/c/Cobalt.htm',
#      '../../wp/c/Chromium.htm',
#      '../../wp/o/Oxygen.htm',
#      '../../wp/w/Water.htm',
#      '../../wp/f/Formic_acid.htm',
#      '../../wp/o/Oxygen.htm',
#      '../../wp/e/Earth%2527s_atmosphere.htm',
#      '../../wp/o/Oxygen.htm',
#      '../../wp/f/Formic_acid.htm',
#      '../../wp/c/Cider.htm',
#      '../../wp/w/Wine.htm',
#      '../../wp/c/Cereal.htm',
#      '../../wp/r/Rice.htm',
#      '../../wp/p/Potato.htm',
#      '../../wp/e/Ethanol.htm',
#      '../../wp/o/Oxygen.htm',
#      '../../wp/w/Water.htm',
#      '../../wp/o/Oxygen.htm',
#      '../../wp/y/Yeast.htm',
#      '../../wp/e/Earth%2527s_atmosphere.htm',
#      '../../wp/c/Carbon_dioxide.htm',
#      '../../wp/h/Hydrogen.htm',
#      '../../wp/c/Carbon_dioxide.htm',
#      '../../wp/h/Hydrogen.htm',
#      '../../wp/w/Water.htm'],
#     'subcategories': [{'name': 'Methanol carbonylation',
#       'num_words': 307,
#       'h3_links': ['../../wp/c/Cobalt.htm',
#        '../../wp/r/Rhodium.htm',
#        '../../wp/b/BP.htm',
#        '../../wp/r/Ruthenium.htm',
#        '../../wp/i/Iridium.htm']},
#      {'name': 'Acetaldehyde oxidation',
#       'num_words': 278,
#       'h3_links': ['../../wp/m/Manganese.htm',
#        '../../wp/c/Cobalt.htm',
#        '../../wp/c/Chromium.htm',
#        '../../wp/o/Oxygen.htm',
#        '../../wp/w/Water.htm',
#        '../../wp/f/Formic_acid.htm',
#        '../../wp/o/Oxygen.htm',
#        '../../wp/e/Earth%2527s_atmosphere.htm',
#        '../../wp/o/Oxygen.htm',
#        '../../wp/f/Formic_acid.htm']},
#      {'name': 'Ethylene oxidation', 'num_words': 0, 'h3_links': []},
#      {'name': 'Fermentation',
#       'num_words': 620,
#       'h3_links': ['../../wp/c/Cider.htm',
#        '../../wp/w/Wine.htm',
#        '../../wp/c/Cereal.htm',
#        '../../wp/r/Rice.htm',
#        '../../wp/p/Potato.htm',
#        '../../wp/e/Ethanol.htm',
#        '../../wp/o/Oxygen.htm',
#        '../../wp/w/Water.htm',
#        '../../wp/o/Oxygen.htm',
#        '../../wp/y/Yeast.htm',
#        '../../wp/e/Earth%2527s_atmosphere.htm',
#        '../../wp/c/Carbon_dioxide.htm',
#        '../../wp/h/Hydrogen.htm',
#        '../../wp/c/Carbon_dioxide.htm',
#        '../../wp/h/Hydrogen.htm',
#        '../../wp/w/Water.htm']}]},
#    {'name': 'Applications',
#     'num_words': 775,
#     'h2_links': ['../../wp/o/Oxygen.htm',
#      '../../wp/p/Palladium.htm',
#      '../../wp/o/Oxygen.htm',
#      '../../wp/t/Textile.htm',
#      '../../wp/b/Box_jellyfish.htm',
#      '../../wp/f/Fungus.htm',
#      '../../wp/t/Textile.htm',
#      '../../wp/p/Pigment.htm'],
#     'subcategories': [{'name': 'Vinyl acetate monomer',
#       'num_words': 86,
#       'h3_links': ['../../wp/o/Oxygen.htm',
#        '../../wp/p/Palladium.htm',
#        '../../wp/o/Oxygen.htm']},
#      {'name': 'Acetic anhydride',
#       'num_words': 95,
#       'h3_links': ['../../wp/t/Textile.htm']},
#      {'name': 'Vinegar', 'num_words': 85, 'h3_links': []},
#      {'name': 'Use as solvent', 'num_words': 205, 'h3_links': []},
#      {'name': 'Other applications',
#       'num_words': 462,
#       'h3_links': ['../../wp/b/Box_jellyfish.htm',
#        '../../wp/f/Fungus.htm',
#        '../../wp/t/Textile.htm',
#        '../../wp/p/Pigment.htm',
#        '../../wp/c/Corrosion.htm']}]},
#    {'name': 'Safety',
#     'num_words': 224,
#     'h2_links': ['../../wp/c/Corrosion.htm'],
#     'subcategories': []}],
#   'tables': [{'class': None,
#     'num_words': 221,
#     'table_links': ['../../wp/p/Phase_%2528matter%2529.htm',
#      '../../wp/e/Ethanol.htm',
#      '../../wp/a/Acetone.htm',
#      '../../wp/t/Toluene.htm',
#      '../../wp/u/United_States.htm',
#      '../../wp/f/Formic_acid.htm',
#      '../../wp/e/Ethanol.htm']},
#    {'class': ['wikitable'], 'num_words': 32, 'table_links': []}]},
#  'Acetone': {'title': 'Acetone',
#   'total_words': 960,
#   'total_links': ['../../wp/p/Phase_%2528matter%2529.htm',
#    '../../wp/e/Ethanol.htm',
#    '../../wp/t/Toluene.htm',
#    '../../wp/e/Ethanol.htm',
#    '../../wp/w/World_War_I.htm',
#    '../../wp/b/Bacteria.htm',
#    '../../wp/i/Israel.htm',
#    '../../wp/b/Bromine.htm',
#    '../../wp/c/Chlorine.htm',
#    '../../wp/s/Sulfuric_acid.htm'],
#   'abstract_length': 348,
#   'abstract_links': ['../../wp/p/Phase_%2528matter%2529.htm',
#    '../../wp/e/Ethanol.htm',
#    '../../wp/t/Toluene.htm',
#    '../../wp/e/Ethanol.htm'],
#   'categories_data': [{'name': 'Uses',
#     'num_words': 355,
#     'h2_links': ['../../wp/w/World_War_I.htm',
#      '../../wp/b/Bacteria.htm',
#      '../../wp/i/Israel.htm'],
#     'subcategories': [{'name': 'Use as an automotive fuel additive',
#       'num_words': 319,
#       'h3_links': ['../../wp/b/Bromine.htm',
#        '../../wp/c/Chlorine.htm',
#        '../../wp/s/Sulfuric_acid.htm']}]},
#    {'name': 'Health effects',
#     'num_words': 228,
#     'h2_links': [],
#     'subcategories': []},
#    {'name': 'Safety',
#     'num_words': 25,
#     'h2_links': ['../../wp/b/Bromine.htm',
#      '../../wp/c/Chlorine.htm',
#      '../../wp/s/Sulfuric_acid.htm'],
#     'subcategories': []}],
#   'tables': [{'class': None,
#     'num_words': 181,
#     'table_links': ['../../wp/p/Phase_%2528matter%2529.htm',
#      '../../wp/e/Ethanol.htm',
#      '../../wp/t/Toluene.htm']}]},
#  'Achilles': {'title': 'Achilles',
#   'total_words': 4446,
#   'total_links': ['../../wp/g/Greek_mythology.htm',
#    '../../wp/t/Trojan_War.htm',
#    '../../wp/h/Homer.htm',
#    '../../wp/z/Zeus.htm',
#    '../../wp/z/Zeus.htm',
#    '../../wp/o/Odysseus.htm',
#    '../../wp/z/Zeus.htm',
#    '../../wp/h/Homer.htm',
#    '../../wp/t/Trojan_War.htm',
#    '../../wp/a/Agamemnon.htm',
#    '../../wp/a/Apollo.htm',
#    '../../wp/o/Odysseus.htm',
#    '../../wp/a/Athena.htm',
#    '../../wp/e/Ethiopia.htm',
#    '../../wp/a/Apollo.htm',
#    '../../wp/d/Danube.htm',
#    '../../wp/h/Heracles.htm',
#    '../../wp/o/Odysseus.htm',
#    '../../wp/a/Athens.htm',
#    '../../wp/b/Black_Sea.htm',
#    '../../wp/r/Romania.htm',
#    '../../wp/u/Ukraine.htm',
#    '../../wp/b/Black_Sea.htm',
#    '../../wp/g/Greece.htm',
#    '../../wp/r/Romanticism.htm',
#    '../../wp/o/Odyssey.htm',
#    '../../wp/b/Black_Sea.htm',
#    '../../wp/p/Plato.htm',
#    '../../wp/a/Alexander_the_Great.htm',
#    '../../wp/t/Trojan_War.htm',
#    '../../wp/h/Homer.htm',
#    '../../wp/p/Plato.htm',
#    '../../wp/w/William_Shakespeare.htm',
#    '../../wp/b/Bob_Dylan.htm',
#    '../../wp/w/World_War_II.htm'],
#   'abstract_length': 188,
#   'abstract_links': ['../../wp/g/Greek_mythology.htm',
#    '../../wp/t/Trojan_War.htm',
#    '../../wp/h/Homer.htm'],
#   'categories_data': [{'name': 'Birth',
#     'num_words': 364,
#     'h2_links': ['../../wp/z/Zeus.htm', '../../wp/z/Zeus.htm'],
#     'subcategories': []},
#    {'name': 'Achilles in the Trojan War',
#     'num_words': 1531,
#     'h2_links': ['../../wp/o/Odysseus.htm',
#      '../../wp/z/Zeus.htm',
#      '../../wp/h/Homer.htm',
#      '../../wp/t/Trojan_War.htm',
#      '../../wp/a/Agamemnon.htm',
#      '../../wp/a/Apollo.htm',
#      '../../wp/o/Odysseus.htm',
#      '../../wp/a/Athena.htm',
#      '../../wp/e/Ethiopia.htm',
#      '../../wp/a/Apollo.htm',
#      '../../wp/d/Danube.htm',
#      '../../wp/h/Heracles.htm',
#      '../../wp/o/Odysseus.htm'],
#     'subcategories': [{'name': 'Hector versus Achilles',
#       'num_words': 1807,
#       'h3_links': ['../../wp/a/Athena.htm',
#        '../../wp/e/Ethiopia.htm',
#        '../../wp/a/Apollo.htm',
#        '../../wp/d/Danube.htm',
#        '../../wp/h/Heracles.htm',
#        '../../wp/o/Odysseus.htm',
#        '../../wp/a/Athens.htm',
#        '../../wp/b/Black_Sea.htm',
#        '../../wp/r/Romania.htm',
#        '../../wp/u/Ukraine.htm',
#        '../../wp/b/Black_Sea.htm']}]},
#    {'name': 'Achilles and Patroclus',
#     'num_words': 111,
#     'h2_links': ['../../wp/a/Athens.htm'],
#     'subcategories': []},
#    {'name': 'The cult of Achilles in antiquity',
#     'num_words': 1010,
#     'h2_links': ['../../wp/b/Black_Sea.htm',
#      '../../wp/r/Romania.htm',
#      '../../wp/u/Ukraine.htm',
#      '../../wp/b/Black_Sea.htm',
#      '../../wp/g/Greece.htm',
#      '../../wp/r/Romanticism.htm'],
#     'subcategories': [{'name': 'The cult of Achilles in modern times: The Achilleion in Corfu',
#       'num_words': 968,
#       'h3_links': ['../../wp/g/Greece.htm',
#        '../../wp/r/Romanticism.htm',
#        '../../wp/o/Odyssey.htm',
#        '../../wp/b/Black_Sea.htm',
#        '../../wp/p/Plato.htm',
#        '../../wp/a/Alexander_the_Great.htm',
#        '../../wp/t/Trojan_War.htm',
#        '../../wp/h/Homer.htm',
#        '../../wp/p/Plato.htm']}]},
#    {'name': 'The name of Achilles',
#     'num_words': 202,
#     'h2_links': [],
#     'subcategories': []},
#    {'name': 'Other stories about Achilles',
#     'num_words': 496,
#     'h2_links': ['../../wp/o/Odyssey.htm',
#      '../../wp/b/Black_Sea.htm',
#      '../../wp/p/Plato.htm',
#      '../../wp/a/Alexander_the_Great.htm'],
#     'subcategories': []},
#    {'name': 'Achilles in Greek tragedy',
#     'num_words': 109,
#     'h2_links': ['../../wp/t/Trojan_War.htm'],
#     'subcategories': []},
#    {'name': 'Spoken-word myths (audio)',
#     'num_words': 56,
#     'h2_links': ['../../wp/h/Homer.htm', '../../wp/p/Plato.htm'],
#     'subcategories': []},
#    {'name': 'Achilles in later art',
#     'num_words': 318,
#     'h2_links': ['../../wp/w/William_Shakespeare.htm',
#      '../../wp/b/Bob_Dylan.htm'],
#     'subcategories': [{'name': 'Drama',
#       'num_words': 26,
#       'h3_links': ['../../wp/w/William_Shakespeare.htm']},
#      {'name': 'Fiction', 'num_words': 37, 'h3_links': []},
#      {'name': 'Film', 'num_words': 63, 'h3_links': []},
#      {'name': 'Television', 'num_words': 29, 'h3_links': []},
#      {'name': 'Music',
#       'num_words': 185,
#       'h3_links': ['../../wp/b/Bob_Dylan.htm',
#        '../../wp/w/World_War_II.htm']}]},
#    {'name': 'Namesakes',
#     'num_words': 26,
#     'h2_links': ['../../wp/w/World_War_II.htm'],
#     'subcategories': []}],
#   'tables': [{'class': None,
#     'num_words': 56,
#     'table_links': ['../../wp/h/Homer.htm', '../../wp/p/Plato.htm']}]},
#  'Achilles tendon': {'title': 'Achilles tendon',
#   'total_words': 893,
#   'total_links': ['../../wp/l/Latin.htm', '../../wp/a/Achilles.htm'],
#   'abstract_length': 108,
#   'abstract_links': ['../../wp/l/Latin.htm'],
#   'categories_data': [{'name': 'Anatomy',
#     'num_words': 167,
#     'h2_links': [],
#     'subcategories': []},
#    {'name': 'Nomenclature',
#     'num_words': 128,
#     'h2_links': ['../../wp/a/Achilles.htm'],
#     'subcategories': []},
#    {'name': 'Role in disease',
#     'num_words': 99,
#     'h2_links': [],
#     'subcategories': []},
#    {'name': 'Treatment of Achilles tendon damage',
#     'num_words': 149,
#     'h2_links': [],
#     'subcategories': []},
#    {'name': 'Achilles tendon damage in popular culture',
#     'num_words': 89,
#     'h2_links': [],
#     'subcategories': []},
#    {'name': 'Additional images',
#     'num_words': 135,
#     'h2_links': [],
#     'subcategories': []}],
#   'tables': [{'class': ['toccolours'],
#     'num_words': 49,
#     'table_links': ['../../wp/l/Latin.htm']},
#    {'class': ['gallery'], 'num_words': 34, 'table_links': []},
#    {'class': ['navbox', 'collapsible', 'autocollapse'],
#     'num_words': 97,
#     'table_links': []}]},
#  'Acid rain': {'title': 'Acid rain',
#   'total_words': 2320,
#   'total_links': ['../../wp/p/Pollution.htm',
#    '../../wp/g/Global_warming.htm',
#    '../../wp/o/Ozone_depletion.htm',
#    '../../wp/s/Smog.htm',
#    '../../wp/i/Invasive_species.htm',
#    '../../wp/k/Kyoto_Protocol.htm',
#    '../../wp/r/Rain.htm',
#    '../../wp/s/Snow.htm',
#    '../../wp/c/Cloud.htm',
#    '../../wp/r/Rain.htm',
#    '../../wp/s/Snow.htm',
#    '../../wp/r/River.htm',
#    '../../wp/f/Forest.htm',
#    '../../wp/p/People%2527s_Republic_of_China.htm',
#    '../../wp/r/Russia.htm',
#    '../../wp/p/Pollution.htm',
#    '../../wp/m/Manchester.htm',
#    '../../wp/e/England.htm',
#    '../../wp/f/Fossil_fuel.htm',
#    '../../wp/e/Earth%2527s_atmosphere.htm',
#    '../../wp/v/Volcano.htm',
#    '../../wp/b/Biology.htm',
#    '../../wp/o/Ocean.htm',
#    '../../wp/g/Glacier.htm',
#    '../../wp/s/Sulfuric_acid.htm',
#    '../../wp/o/Ozone.htm',
#    '../../wp/h/Hydrogen_peroxide.htm',
#    '../../wp/o/Oxygen.htm',
#    '../../wp/i/Iron.htm',
#    '../../wp/m/Manganese.htm',
#    '../../wp/g/Gypsum.htm'],
#   'abstract_length': 500,
#   'abstract_links': ['../../wp/p/Pollution.htm',
#    '../../wp/g/Global_warming.htm',
#    '../../wp/o/Ozone_depletion.htm',
#    '../../wp/s/Smog.htm',
#    '../../wp/i/Invasive_species.htm',
#    '../../wp/k/Kyoto_Protocol.htm',
#    '../../wp/r/Rain.htm',
#    '../../wp/s/Snow.htm',
#    '../../wp/c/Cloud.htm',
#    '../../wp/r/Rain.htm',
#    '../../wp/s/Snow.htm',
#    '../../wp/r/River.htm',
#    '../../wp/f/Forest.htm'],
#   'categories_data': [{'name': 'History and trends',
#     'num_words': 346,
#     'h2_links': ['../../wp/p/People%2527s_Republic_of_China.htm',
#      '../../wp/r/Russia.htm',
#      '../../wp/p/Pollution.htm',
#      '../../wp/m/Manchester.htm',
#      '../../wp/e/England.htm'],
#     'subcategories': []},
#    {'name': 'Emissions of chemicals leading to acidification',
#     'num_words': 427,
#     'h2_links': ['../../wp/f/Fossil_fuel.htm',
#      '../../wp/e/Earth%2527s_atmosphere.htm',
#      '../../wp/v/Volcano.htm',
#      '../../wp/b/Biology.htm',
#      '../../wp/o/Ocean.htm',
#      '../../wp/g/Glacier.htm',
#      '../../wp/s/Sulfuric_acid.htm',
#      '../../wp/o/Ozone.htm',
#      '../../wp/h/Hydrogen_peroxide.htm',
#      '../../wp/o/Oxygen.htm',
#      '../../wp/i/Iron.htm',
#      '../../wp/m/Manganese.htm'],
#     'subcategories': [{'name': 'Natural Phenomena',
#       'num_words': 64,
#       'h3_links': ['../../wp/e/Earth%2527s_atmosphere.htm',
#        '../../wp/v/Volcano.htm',
#        '../../wp/b/Biology.htm',
#        '../../wp/o/Ocean.htm',
#        '../../wp/g/Glacier.htm']},
#      {'name': 'Human gas', 'num_words': 49, 'h3_links': []},
#      {'name': 'Gas phase chemistry',
#       'num_words': 100,
#       'h3_links': ['../../wp/s/Sulfuric_acid.htm']},
#      {'name': 'Chemistry in cloud droplets',
#       'num_words': 161,
#       'h3_links': ['../../wp/o/Ozone.htm',
#        '../../wp/h/Hydrogen_peroxide.htm',
#        '../../wp/o/Oxygen.htm',
#        '../../wp/i/Iron.htm',
#        '../../wp/m/Manganese.htm']}]},
#    {'name': 'Acid deposition',
#     'num_words': 134,
#     'h2_links': [],
#     'subcategories': [{'name': 'Wet deposition',
#       'num_words': 69,
#       'h3_links': []},
#      {'name': 'Dry deposition', 'num_words': 115, 'h3_links': []}]},
#    {'name': 'Adverse effects',
#     'num_words': 547,
#     'h2_links': [],
#     'subcategories': [{'name': 'Surface waters and aquatic animals',
#       'num_words': 74,
#       'h3_links': []},
#      {'name': 'Soils', 'num_words': 62, 'h3_links': []},
#      {'name': 'Forests and other vegetation',
#       'num_words': 160,
#       'h3_links': []},
#      {'name': 'Human health', 'num_words': 64, 'h3_links': []},
#      {'name': 'Other adverse effects', 'num_words': 122, 'h3_links': []}]},
#    {'name': 'Prevention methods',
#     'num_words': 351,
#     'h2_links': ['../../wp/g/Gypsum.htm'],
#     'subcategories': [{'name': 'Technical solutions',
#       'num_words': 188,
#       'h3_links': ['../../wp/g/Gypsum.htm']},
#      {'name': 'International treaties', 'num_words': 28, 'h3_links': []},
#      {'name': 'Emissions trading', 'num_words': 109, 'h3_links': []}]}],
#   'tables': [{'class': ['toccolours', 'collapsible'],
#     'num_words': 175,
#     'table_links': ['../../wp/p/Pollution.htm',
#      '../../wp/g/Global_warming.htm',
#      '../../wp/o/Ozone_depletion.htm',
#      '../../wp/s/Smog.htm',
#      '../../wp/i/Invasive_species.htm',
#      '../../wp/k/Kyoto_Protocol.htm']}]}}
